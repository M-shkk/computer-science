# %%
name = "Студент"

# %%
a = 10

# %%
b = 5

# %%
result = a + b

# %%
print(f"Привет, {name}!")
# Out:
# Привет, Студент!

# %%
print(f"Результат сложения {a} + {b} равен {result}")
# Out:
# Результат сложения 10 + 5 равен 15
